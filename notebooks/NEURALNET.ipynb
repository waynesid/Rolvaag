# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch.optim.lr_scheduler as lr_scheduler

# %%
#load the team related datasets into the notebook and save them as dataframes
def country_df(csv):
  df = pd.read_csv(csv)
  df.sort_values('HomeTeam', inplace=True)
  df.reset_index(inplace=True)
  df.drop("index", axis =1 , inplace=True)

  return df

df_france = country_df('FootballData/F1.csv')
df_spain  = country_df('FootballData/SP1.csv')
df_england  = country_df('FootballData/E0.csv')
df_championship  = country_df('FootballData/E1.csv')
#df_finland  = country_df('/content/drive/MyDrive/FootballData/FIN.csv')
#df_germany = country_df('FootballData/D1.csv')
df_england_22 = country_df('FootballData/E0_22.csv')
df_spa_22 = country_df('FootballData/SP1_22.csv')
#df_jpn = country_df('FootballData/JPN.csv')
df_ita = country_df('FootballData/I1.csv')
df_E1 = country_df('FootballData/E1.csv')
df_E2 = country_df('FootballData/E2.csv')
df_E3 = country_df('FootballData/E3.csv')
df_EC = country_df('FootballData/EC.csv')
df_F2 = country_df('FootballData/F2.csv')
df_I2 = country_df('FootballData/I2.csv')
df_dataE0 = country_df('FootballData/data (9)/E0.csv')
df_dataE1 = country_df('FootballData/data (9)/E1.csv')
df_dataE2 = country_df('FootballData/data (9)/E2.csv')
df_dataE3 = country_df('FootballData/data (9)/E3.csv')
df_dataEC = country_df('FootballData/data (9)/EC.csv')
df_dataF2 = country_df('FootballData/data (9)/F2.csv')
df_dataG1 = country_df('FootballData/data (9)/G1.csv')
df_dataN1 = country_df('FootballData/data (9)/N1.csv')
df_dataP1 = country_df('FootballData/data (9)/P1.csv')
df_dataSC0 = country_df('FootballData/data (9)/SC0.csv')
df_dataSC1 = country_df('FootballData/data (9)/SC1.csv')
df_dataSC2 = country_df('FootballData/data (9)/SC2.csv')
df_dataSC3 = country_df('FootballData/data (9)/SC3.csv')
df_dataSP2 = country_df('FootballData/data (9)/SP2.csv')
df_dataSP1 = country_df('FootballData/data (9)/SP1.csv')
df_dataT1 = country_df('FootballData/data (9)/T1.csv')

df_data8E0 = country_df('FootballData/data (8)/E0.csv')
df_data8E1 = country_df('FootballData/data (8)/E1.csv')
df_data8E2 = country_df('FootballData/data (8)/E2.csv')
df_data8E3 = country_df('FootballData/data (8)/E3.csv')
df_data8EC = country_df('FootballData/data (8)/EC.csv')
#df_data8F2 = country_df('FootballData/data (8)/F2.csv')
df_data8G1 = country_df('FootballData/data (8)/G1.csv')
#df_data8N1 = country_df('FootballData/data (8)/N1.csv')
#df_data8P1 = country_df('FootballData/data (8)/P1.csv')
df_data8SC0 = country_df('FootballData/data (8)/SC0.csv')
df_data8SC1 = country_df('FootballData/data (8)/SC1.csv')
df_data8SC2 = country_df('FootballData/data (8)/SC2.csv')
df_data8SC3 = country_df('FootballData/data (8)/SC3.csv')
#df_data8SP2 = country_df('FootballData/data (8)/SP2.csv')
df_data8SP1 = country_df('FootballData/data (8)/SP1.csv')
df_data8T1 = country_df('FootballData/data (8)/T1.csv')
df_B1 = country_df('FootballData/B1.csv')

df_data7E0 = country_df('FootballData/data (7)/E0.csv')
df_data7E1 = country_df('FootballData/data (7)/E1.csv')
df_data7E2 = country_df('FootballData/data (7)/E2.csv')
df_data7E3 = country_df('FootballData/data (7)/E3.csv')
df_data7EC = country_df('FootballData/data (7)/EC.csv')
df_data7F2 = country_df('FootballData/data (7)/F2.csv')
df_data7G1 = country_df('FootballData/data (7)/G1.csv')
df_data7N1 = country_df('FootballData/data (7)/N1.csv')
df_data7P1 = country_df('FootballData/data (7)/P1.csv')
df_data7SC0 = country_df('FootballData/data (7)/SC0.csv')
df_data7SC1 = country_df('FootballData/data (7)/SC1.csv')
df_data7SC2 = country_df('FootballData/data (7)/SC2.csv')
df_data7SC3 = country_df('FootballData/data (7)/SC3.csv')
df_data7SP2 = country_df('FootballData/data (7)/SP2.csv')
df_data7SP1 = country_df('FootballData/data (7)/SP1.csv')
#df_data7T1 = country_df('FootballData/data (7)/T1.csv')




data = pd.concat([df_france, df_spain, df_england, df_championship, df_england_22, df_spa_22, df_ita,df_E1,df_E2,df_E3,df_EC,df_F2,df_I2,df_dataE0,df_dataE1,df_dataE2,df_dataE3,df_dataEC,df_dataF2,df_dataG1,df_dataN1,df_dataP1,df_dataSC0,df_dataSC1,df_dataSC2,df_dataSC3,df_dataSP1,df_dataSP2,df_dataT1,
                  df_data8E0,df_data8E1,df_data8E2,df_data8E3,df_data8EC,df_data8G1,df_data8SC0,df_data8SC1,df_data8SC2,df_data8SC3,df_data8SP1,df_data8T1,
                  df_data7E0,df_data7E1,df_data7E2,df_data7E3,df_data7EC,df_data7G1,df_data7SC0,df_data7SC1,df_data7SC2,df_data7SC3,df_data7SP1,df_data7SP2,df_data7P1,df_data7N1,df_data7F2], sort = False)

# %%
data.shape
# Out:
# (21108, 139)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21108 entries, 0 to 379
# Columns: 139 entries, Div to BSA
# dtypes: float64(129), int64(2), object(8)
# memory usage: 22.5+ MB

# %%
data.isna().sum()
# Out:
# Div             0
# Date            0
# HomeTeam        0
# AwayTeam        0
# FTHG            0
#             ...
# AvgCAHH     20348
# AvgCAHA     20348
# BSH         11187
# BSD         11187
# BSA         11187
# Length: 139, dtype: int64

# %%
data.describe()
# Out:
#                FTHG          FTAG          HTHG          HTAG            HS  \
# count  21108.000000  21108.000000  21107.000000  21107.000000  14523.000000
# mean       1.438933      1.099536      0.641683      0.481594     11.995180
# std        1.222689      1.067572      0.802991      0.694211      4.611663
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      0.000000      0.000000      0.000000      9.000000
# 50%        1.000000      1.000000      0.000000      0.000000     12.000000
# 75%        2.000000      2.000000      1.000000      1.000000     15.000000
# max        9.000000      9.000000      6.000000      5.000000     44.000000
#
#                  AS           HST           AST            HY            AY  \
# count  14523.000000  14523.000000  14523.000000  14538.000000  14538.000000
# mean       9.541761      5.745301      4.531639      1.449099      1.830513
# std        4.067156      2.980297      2.594744      1.246770      1.362243
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        7.000000      4.000000      3.000000      0.000000      1.000000
# 50%        9.000000      5.000000      4.000000      1.000000      2.000000
# 75%       12.000000      7.000000      6.000000      2.000000      3.000000
# max       33.000000     24.000000     18.000000      8.000000      9.000000
#
#        ...    B365CAHA       PCAHH       PCAHA     MaxCAHH     MaxCAHA  \
# count  ...  759.000000  760.000000  760.000000  760.000000  760.000000
# mean   ...    1.957036    1.962368    1.967145    2.021408    2.027342
# std    ...    0.099912    0.104936    0.104870    0.104814    0.109980
# min    ...    1.580000    1.710000    1.610000    1.810000    1.650000
# 25%    ...    1.880000    1.880000    1.880000    1.940000    1.940000
# 50%    ...    1.960000    1.960000    1.960000    2.015000    2.020000
# 75%    ...    2.040000    2.040000    2.050000    2.102500    2.110000
# max    ...    2.200000    2.480000    2.270000    2.520000    2.310000
#
#           AvgCAHH     AvgCAHA          BSH          BSD          BSA
# count  760.000000  760.000000  9921.000000  9921.000000  9921.000000
# mean     1.936118    1.940961     2.287810     3.413472     3.787174
# std      0.094286    0.093737     0.989092     0.486010     2.086802
# min      1.730000    1.600000     1.080000     2.620000     1.050000
# 25%      1.860000    1.860000     1.730000     3.250000     2.600000
# 50%      1.935000    1.940000     2.100000     3.250000     3.200000
# 75%      2.010000    2.020000     2.500000     3.500000     4.330000
# max      2.420000    2.200000    23.000000     9.000000    23.000000
#
# [8 rows x 131 columns]

# %%
data['HomeTeam'].unique()
# Out:
# array(['Ajaccio', 'Auxerre', 'Bordeaux', 'Le Mans', 'Lens', 'Lille',
#        'Lyon', 'Marseille', 'Metz', 'Monaco', 'Nancy', 'Nantes', 'Nice',
#        'Paris SG', 'Rennes', 'Sochaux', 'St Etienne', 'Strasbourg',
#        'Toulouse', 'Troyes', 'Alaves', 'Ath Bilbao', 'Ath Madrid',
#        'Barcelona', 'Betis', 'Cadiz', 'Celta', 'Espanol', 'Getafe',
#        'La Coruna', 'Malaga', 'Mallorca', 'Osasuna', 'Real Madrid',
#        'Santander', 'Sevilla', 'Sociedad', 'Valencia', 'Villarreal',
#        'Zaragoza', 'Arsenal', 'Aston Villa', 'Birmingham', 'Blackburn',
#        'Bolton', 'Charlton', 'Chelsea', 'Everton', 'Fulham', 'Liverpool',
#        'Man City', 'Man United', 'Middlesbrough', 'Newcastle',
#        'Portsmouth', 'Sunderland', 'Tottenham', 'West Brom', 'West Ham',
#        'Wigan', 'Brighton', 'Burnley', 'Cardiff', 'Coventry', 'Crewe',
#        'Crystal Palace', 'Derby', 'Hull', 'Ipswich', 'Leeds', 'Leicester',
#        'Luton', 'Millwall', 'Norwich', 'Plymouth', 'Preston', 'QPR',
#        'Reading', 'Sheffield United', 'Sheffield Weds', 'Southampton',
#        'Stoke', 'Watford', 'Wolves', 'Bournemouth', 'Brentford',
#        "Nott'm Forest", 'Elche', 'Granada', 'Levante', 'Vallecano',
#        'Ascoli', 'Cagliari', 'Chievo', 'Empoli', 'Fiorentina', 'Inter',
#        'Juventus', 'Lazio', 'Lecce', 'Livorno', 'Messina', 'Milan',
#        'Palermo', 'Parma', 'Reggina', 'Roma', 'Sampdoria', 'Siena',
#        'Treviso', 'Udinese', 'Barnsley', 'Blackpool', 'Bradford',
#        'Bristol City', 'Chesterfield', 'Colchester', 'Doncaster',
#        'Gillingham', 'Hartlepool', 'Huddersfield', 'Milton Keynes Dons',
#        'Oldham', 'Port Vale', 'Rotherham', 'Scunthorpe', 'Southend',
#        'Swansea', 'Swindon', 'Tranmere', 'Walsall', 'Yeovil', 'Barnet',
#        'Boston', 'Bristol Rvs', 'Bury', 'Carlisle', 'Cheltenham',
#        'Chester', 'Darlington', 'Grimsby', 'Leyton Orient', 'Lincoln',
#        'Macclesfield', 'Mansfield', 'Northampton', 'Notts County',
#        'Oxford', 'Peterboro', 'Rochdale', 'Rushden & D', 'Shrewsbury',
#        'Stockport', 'Torquay', 'Wrexham', 'Wycombe', 'Accrington',
#        'Aldershot', 'Altrincham', 'Burton', 'Cambridge', 'Canvey Island',
#        'Crawley Town', 'Dag and Red', 'Exeter', 'Forest Green',
#        'Gravesend', 'Grays', 'Halifax', 'Hereford', 'Kidderminster',
#        'Morecambe', 'Scarborough', 'Southport', 'Stevenage', 'Tamworth',
#        'Woking', 'York', 'Amiens', 'Bastia', 'Brest', 'Caen',
#        'Chateauroux', 'Clermont', 'Creteil', 'Dijon', 'Grenoble',
#        'Gueugnon', 'Guingamp', 'Istres', 'Laval', 'Le Havre', 'Lorient',
#        'Montpellier', 'Reims', 'Sedan', 'Sete', 'Valenciennes',
#        'Albinoleffe', 'Arezzo', 'Atalanta', 'Avellino', 'Bari', 'Bologna',
#        'Brescia', 'Catania', 'Catanzaro', 'Cesena', 'Cremonese',
#        'Crotone', 'Mantova', 'Modena', 'Pescara', 'Piacenza', 'Rimini',
#        'Ternana', 'Torino', 'Triestina', 'Verona', 'Vicenza', 'Barrow',
#        'Eastbourne Borough', 'Ebbsfleet', 'Histon', 'Kettering Town',
#        'Lewes', 'Northwich', 'Salisbury', 'Weymouth', 'Angers',
#        'Boulogne', 'Nimes', 'Tours', 'Vannes', 'AEK', 'Aris',
#        'Asteras Tripolis', 'Ergotelis', 'Iraklis', 'Larisa',
#        'Levadeiakos', 'OFI', 'Olympiakos', 'PAOK', 'Panathinaikos',
#        'Panionios', 'Panserraikos', 'Panthrakikos', 'Thrasyvoulos',
#        'Xanthi', 'AZ Alkmaar', 'Ajax', 'Den Haag', 'Feyenoord',
#        'Graafschap', 'Groningen', 'Heerenveen', 'Heracles', 'NAC Breda',
#        'Nijmegen', 'PSV Eindhoven', 'Roda JC', 'Sparta', 'Twente',
#        'Utrecht', 'Vitesse', 'Volendam', 'Willem II', 'Academica',
#        'Belenenses', 'Benfica', 'Est Amadora', 'Guimaraes', 'Leixoes',
#        'Maritimo', 'Nacional', 'Naval', 'Pacos Ferreira', 'Porto',
#        'Rio Ave', 'Setubal', 'Sp Braga', 'Sp Lisbon', 'Trofense',
#        'Aberdeen', 'Celtic', 'Dundee United', 'Falkirk', 'Hamilton',
#        'Hearts', 'Hibernian', 'Inverness C', 'Kilmarnock', 'Motherwell',
#        'Rangers', 'St Mirren', 'Airdrie Utd', 'Clyde', 'Dundee',
#        'Dunfermline', 'Livingston', 'Morton', 'Partick', 'Queen of Sth',
#        'Ross County', 'St Johnstone', 'Alloa', 'Arbroath', 'Ayr',
#        'Brechin', 'East Fife', 'Peterhead', 'Queens Park', 'Raith Rvs',
#        'Stirling', 'Stranraer', 'Albion Rvs', 'Annan Athletic', 'Berwick',
#        'Cowdenbeath', 'Dumbarton', 'East Stirling', 'Elgin', 'Forfar',
#        'Montrose', 'Stenhousemuir', 'Almeria', 'Numancia', 'Recreativo',
#        'Sp Gijon', 'Valladolid', 'Albacete', 'Alicante', 'Castellon',
#        'Cordoba', 'Eibar', 'Gimnastic', 'Girona', 'Hercules', 'Huesca',
#        'Las Palmas', 'Murcia', 'Salamanca', 'Sevilla B', 'Tenerife',
#        'Xerez', 'Ankaragucu', 'Ankaraspor', 'Antalyaspor', 'Besiktas',
#        'Bursaspor', 'Buyuksehyr', 'Denizlispor', 'Eskisehirspor',
#        'Fenerbahce', 'Galatasaray', 'Gaziantepspor', 'Genclerbirligi',
#        'Hacettepespor', 'Kayserispor', 'Kocaelispor', 'Konyaspor',
#        'Sivasspor', 'Trabzonspor', 'Droylsden', 'Farsley',
#        'Stafford Rangers', 'Atromitos', 'Kalamaria', 'Veria', 'Gretna',
#        'Kasimpasa', 'Manisaspor', 'Oftasspor', 'Rizespor', 'St. Albans',
#        'Egaleo', 'Ionikos', 'Kerkyra', 'Ciudad de Murcia', 'Lorca',
#        'Poli Ejido', 'Ponferradina', 'Real Madrid B', 'Vecindario',
#        'Aves', 'Beira Mar', 'Boavista', 'Leiria', 'Excelsior', 'Waalwijk',
#        'Libourne', 'Niort'], dtype=object)

# %% [markdown]
# VISUALIZATIONS

# %%
data.plot(kind='box', figsize=(12,8))
# Out:
# <Axes: >

# %%
#Home Goals
data.plot(kind='hist',
           y='FTHG', 
           bins = 5,
           # figsize=(12,8)
           )

#Away goals
data.plot(kind="hist", 
          y='FTAG',
          bins = 5,
          alpha = 0.3,
          #figsize=(12,8)
          )
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Grouping by HomeTeam
df_bar = data.groupby(["HomeTeam"])["FTHG"].mean()

#Bar plot
df_bar.plot(
    kind="bar",
    ylabel="Home goals scored",
    xlabel="Home Team",
    title="Average Home goals Socred by Home Teams",
    figsize=(15,5)
)
# Out:
# <Axes: title={'center': 'Average Home goals Socred by Home Teams'}, xlabel='Home Team', ylabel='Home goals scored'>

# %%
#Grouping by AwayTeam
df_bar = data.groupby(["AwayTeam"])["FTHG"].mean()

#Bar plot
df_bar.plot(
    kind="bar",
    ylabel="Away goals scored",
    xlabel="Away Team",
    title="Average Away goals Socred by Away Teams",
    figsize=(15,5)
)
# Out:
# <Axes: title={'center': 'Average Away goals Socred by Away Teams'}, xlabel='Away Team', ylabel='Away goals scored'>

# %%
data.plot(
    kind="scatter",
    x="HF",
    y="HY",
    xlabel="Fouls made by Home team",
    ylabel="number of yellow cars received by home teams",
    title="relationship b/w fouls made and yellow card issued",
    figsize=(15,5)
)
# Out:
# <Axes: title={'center': 'relationship b/w fouls made and yellow card issued'}, xlabel='Fouls made by Home team', ylabel='number of yellow cars received by home teams'>

# %%
df_2 = data.filter(items = ["FTHG", "FTAG", "FTR","HS","AS" ,"HY","AY","B365H","B365D","B365A"])

df_2['FTR'] = df_2['FTR'].map({'H':0,'D':1,'A':2})

# %%
df_2.head()
# Out:
#    FTHG  FTAG  FTR    HS    AS   HY   AY  B365H  B365D  B365A
# 0     1     3    2   5.0   8.0  1.0  3.0    5.0   3.30   1.61
# 1     1     0    0  10.0  12.0  2.0  1.0    3.0   2.87   2.30
# 2     1     0    0  16.0   7.0  0.0  0.0    2.2   2.75   3.40
# 3     0     0    1  15.0  10.0  2.0  4.0    1.9   2.87   4.20
# 4     3     1    0   6.0   2.0  2.0  2.0    2.4   3.00   2.70

# %%
#generate and print pairwise correlation columns
cm = df_2.corr()
#print(cm)

#plot the correlation matrix nicely using seaborn
plt.figure(figsize=(20,9))
sns.heatmap(cm, annot=True)
plt.show()

# %%
#data = data[["FTHG","FTAG","FTR","HS","AS","HST","AST","HC","AC"]]


columns =["FTHG","FTAG","HST","AST","HS","AS","B365H","B365D","B365A","HY","AY","FTR"] 
data = data[columns]

for i in data.columns[data.isnull().any(axis=0)]:     #---Applying Only on variables with NaN values
    data[i].fillna(data[i].mean(),inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10292\3292793120.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i].fillna(data[i].mean(),inplace=True)

# %%
data.shape
# Out:
# (21108, 12)

# %%
data.head()
# Out:
#    FTHG  FTAG  HST  AST    HS    AS  B365H  B365D  B365A   HY   AY FTR
# 0     1     3  3.0  4.0   5.0   8.0    5.0   3.30   1.61  1.0  3.0   A
# 1     1     0  2.0  2.0  10.0  12.0    3.0   2.87   2.30  2.0  1.0   H
# 2     1     0  8.0  3.0  16.0   7.0    2.2   2.75   3.40  0.0  0.0   H
# 3     0     0  7.0  5.0  15.0  10.0    1.9   2.87   4.20  2.0  4.0   D
# 4     3     1  3.0  0.0   6.0   2.0    2.4   3.00   2.70  2.0  2.0   H

# %%
data.isna().sum()
# Out:
# FTHG     0
# FTAG     0
# HST      0
# AST      0
# HS       0
# AS       0
# B365H    0
# B365D    0
# B365A    0
# HY       0
# AY       0
# FTR      0
# dtype: int64

# %%
data.loc[data.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [FTHG, FTAG, HST, AST, HS, AS, B365H, B365D, B365A, HY, AY, FTR]
# Index: []

# %%
# Create a boolean mask for rows with NaN values
mask = data.isnull().any(axis=1)

# Delete rows using the mask
data = data[~mask]

# %%
data['FTR'] = data['FTR'].map({'H':0,'D':1,'A':2})

# %%
#adding .values for the neural network
X=data.drop("FTR", axis=1).values
Y=data["FTR"].values

# %%
X.shape
# Out:
# (21108, 11)

# %%
Y.shape
# Out:
# (21108,)

# %%
from sklearn.preprocessing import StandardScaler
# Scale data to have mean 0 and variance 1 
# which is importance for convergence of the neural network
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split the data to train and test dataset.
import sklearn
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y, test_size=0.1)

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable

# %%
X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)
y_train = torch.LongTensor(y_train)
y_test = torch.LongTensor(y_test)

# %%
class NeuralNetworkClassificationModel(nn.Module):
    def __init__(self,input_dim,output_dim):
        super(NeuralNetworkClassificationModel,self).__init__()
        self.input_layer    = nn.Linear(input_dim,256)
        self.hidden_layer1  = nn.Linear(256,128)
        self.hidden_layer2  = nn.Linear(128,64)
        self.hidden_layer3  = nn.Linear(64,16)
        self.output_layer   = nn.Linear(16,output_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.1)  # Add this line
        self.softmax = nn.Softmax(dim=1)
    
    def forward(self,x):
        out =  self.dropout(self.relu(self.input_layer(x)))
        out =  self.dropout(self.relu(self.hidden_layer1(out)))
        out =  self.dropout(self.relu(self.hidden_layer2(out)))
        out =  self.dropout(self.relu(self.hidden_layer3(out)))
        out =  self.output_layer(out)
        out =  self.softmax(out)
        return out

# %%
input_dim  = 11
output_dim = 3
model = NeuralNetworkClassificationModel(input_dim,output_dim)

# %%
from torch.utils.data import TensorDataset, DataLoader

# Define batch size.
batch_size =3000

# Create Tensor datasets.
train_data = TensorDataset(X_train, y_train)
test_data = TensorDataset(X_test, y_test)

# Create DataLoaders.
dataloader_train = DataLoader(train_data, shuffle=True, batch_size=batch_size)
dataloader_test = DataLoader(test_data, shuffle=True, batch_size=batch_size)

# %%
learning_rate = 1e-3
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate)

# Define your learning rate schedule
scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.001)

# %%
#hyperparameters to consider ; momentum=int, nesterov=boolean,decay_rate=(int) learning_rate/epochs -->these are in the optimizer field
#adding batch size in training
train_losses = []
test_losses = []

# %%
def train_network(model, optimizer, criterion, dataloader_train, dataloader_test, num_epochs, train_losses, test_losses):
    for epoch in range(num_epochs):
        # Training
        model.train()
        for X_train, y_train in dataloader_train:
            # Clear out the gradients from the last step (loss.backward()).
            optimizer.zero_grad()

            # Forward feed.
            output_train = model(X_train)

            # Calculate the loss.
            loss_train = criterion(output_train, y_train)

            # Backward propagation: calculate gradients.
            loss_train.backward()

            # Update the weights.
            scheduler.step()

            # Record the loss.
            import numpy as np

            # Record the loss.
            train_losses = np.append(train_losses, loss_train.item())


        # Evaluation
        model.eval()
        with torch.no_grad():
            for X_test, y_test in dataloader_test:
                output_test = model(X_test)
                loss_test = criterion(output_test, y_test)

                # Record the loss.
                test_losses = np.append(loss_test, loss_test.item())

        if (epoch + 1) % 100 == 0:
            print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {np.mean(train_losses):.7f}, Test Loss: {np.mean(test_losses):.7f}")

    return train_losses, test_losses

# %%
num_epochs = 500

# %%
train_network(model, optimizer, criterion, dataloader_train, dataloader_test, num_epochs, train_losses, test_losses)
# Out:
# c:\Users\USER\Wayne\Rolvaag\.venv\Lib\site-packages\torch\optim\lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Epoch 100/500, Train Loss: 1.1015207, Test Loss: 1.1000916
# Epoch 200/500, Train Loss: 1.1015257, Test Loss: 1.1000916
# Epoch 300/500, Train Loss: 1.1015226, Test Loss: 1.1000916
# Epoch 400/500, Train Loss: 1.1015216, Test Loss: 1.1000915
# Epoch 500/500, Train Loss: 1.1015145, Test Loss: 1.1000916
# (array([1.10346806, 1.09961963, 1.10214055, ..., 1.10164905, 1.10037911,
#         1.103737  ]),
#  array([1.10009158, 1.10009158]))

# %%
predictions_train = []
predictions_test =  []
with torch.no_grad():
    predictions_train = model(X_train)
    predictions_test = model(X_test)

# %%
def get_accuracy_multiclass(pred_arr,original_arr):
    if len(pred_arr)!=len(original_arr):
        return False
    pred_arr = pred_arr.numpy()
    original_arr = original_arr.numpy()
    final_pred= []
    # we will get something like this in the pred_arr [32.1680,12.9350,-58.4877]
    # so will be taking the index of that argument which has the highest value here 32.1680 which corresponds to 0th index
    for i in range(len(pred_arr)):
        final_pred.append(np.argmax(pred_arr[i]))
    final_pred = np.array(final_pred)
    count = 0
    #here we are doing a simple comparison between the predicted_arr and the original_arr to get the final accuracy
    for i in range(len(original_arr)):
        if final_pred[i] == original_arr[i]:
            count+=1
    return count/len(final_pred)

# %%
train_acc = get_accuracy_multiclass(predictions_train,y_train)
test_acc  = get_accuracy_multiclass(predictions_test,y_test)

# %%
print(f"Training Accuracy: {train_acc}")
print(f"Test Accuracy: {test_acc}")
# Out:
# Training Accuracy: 0.28362373006264147
# Test Accuracy: 0.29417337754618667

# %%
#["FTHG","FTAG","HTHG","HTAG","Form","B365H","B365D","B365A"]
X_new = np.array([[1.08,1.08,1.00,1.60,2.54,3.30,2.96]])
X_net = torch.FloatTensor(X_new)

# %%
from sklearn import preprocessing


torch.manual_seed(42)
# During inference or evaluation, apply softmax to obtain class probabilities
model.eval()
with torch.no_grad():
    prediction = model(X_net)

  # prediction = preprocessing.scale(prediction)

    print("Prediction of Games: {}".format(prediction))


# Assuming prediction is a 1D tensor with 3 elements
prediction_np = prediction.numpy().flatten()

# Calculate the differences
diff_12 = prediction_np[1] - prediction_np[0]
diff_23 = prediction_np[2] - prediction_np[1]
diff_31 = prediction_np[0] - prediction_np[2]

# Find the maximum and minimum
max_val = np.max(prediction_np)
min_val = np.min(prediction_np)

# Create a DataFrame
df = pd.DataFrame({
    'Difference 1-2': [diff_12],
    'Difference 2-3': [diff_23],
    'Difference 3-1': [diff_31],
    'Maximum': [max_val],
    'Minimum': [min_val]
})

print(df)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[129], line 8
#       6 model.eval()
#       7 with torch.no_grad():
# ----> 8     prediction = model(X_net)
#      10   # prediction = preprocessing.scale(prediction)
#      12     print("Prediction of Games: {}".format(prediction))
#
# File c:\Users\USER\Wayne\Rolvaag\.venv\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\USER\Wayne\Rolvaag\.venv\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[116], line 14, in NeuralNetworkClassificationModel.forward(self, x)
#      13 def forward(self,x):
# ---> 14     out =  self.dropout(self.relu(self.input_layer(x)))
#      15     out =  self.dropout(self.relu(self.hidden_layer1(out)))
#      16     out =  self.dropout(self.relu(self.hidden_layer2(out)))
#
# File c:\Users\USER\Wayne\Rolvaag\.venv\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\USER\Wayne\Rolvaag\.venv\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\USER\Wayne\Rolvaag\.venv\Lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x7 and 11x256)

# %%
#import pickle

# Create Pickle file from the Neural network Model
#with open('neuralnet.pickle', 'wb') as dump_var:
 #   pickle.dump(data, dump_var)

# %%
#pickle.dump(model, open('model.pkl', 'wb'))

# %%
#pickled_model = pickle.load(open('model.pkl', 'rb'))
#pickled_model(X_net)
